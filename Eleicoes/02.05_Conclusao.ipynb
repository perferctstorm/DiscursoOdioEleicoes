# %%
#instalando a versão do pacote de visualização Vega-Altair com a mesma versão que os plots foram construídos
# !pip install altair=="5.4.1"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 658.1/658.1 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: altair
#     Found existing installation: altair 5.5.0
#     Uninstalling altair-5.5.0:
#       Successfully uninstalled altair-5.5.0
# ...

# %%
#!pip install "vegafusion[embed]"
# !pip install "vegafusion[embed]==1.6.9"
# !pip install "vegafusion-python-embed==1.6.9"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.1/25.1 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 15.4 MB/s eta 0:00:00
# ...

# %%
import polars as pl
from polars import selectors as cs
import altair as alt
import numpy as np
